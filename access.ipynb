# %% [markdown]
# acess single elements

# %%
import pandas as pd
data={
    "Name":["Shree","Anu","Sam","Ritu","Gyan"],
    "Age":[10,20,30,40,50],
    "City":["Indore","Dhar","Bihar","Patna","Delhi"]
}
rd=pd.DataFrame(data)
print(rd['Name'])
# Out:
# 0    Shree
# 1      Anu
# 2      Sam
# 3     Ritu
# 4     Gyan
# Name: Name, dtype: object

# %% [markdown]
# acess multiple elements

# %%
import pandas as pd
data={
    "Name":["Shree","Anu","Sam","Ritu","Gyan"],
    "Age":[10,20,30,40,50],
    "City":["Indore","Dhar","Bihar","Patna","Delhi"]
}
rd=pd.DataFrame(data)
print(rd[["Name","City"]])
# Out:
#     Name    City
# 0  Shree  Indore
# 1    Anu    Dhar
# 2    Sam   Bihar
# 3   Ritu   Patna
# 4   Gyan   Delhi
